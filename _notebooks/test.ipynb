# %%
import numpy as np
import pandas
import dill 
import pickle
import tensorly
import matplotlib.pyplot as plt
import sys 
sys.path.append("../_src/")

sys.path.append("../_src/AGH/")

from AGH import AGH

# %%
p="../_out/test/train_ratio_0.7/rank_5/gamma_1/niter_3"

# %%
a=np.load(p+"loss_logs.npy")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [4], in <cell line: 1>()
# ----> 1 a=np.load(p+"loss_logs.npy")
#
# File ~/.cache/pypoetry/virtualenvs/tensor-decompositions-kshbHvMa-py3.9/lib/python3.9/site-packages/numpy/lib/npyio.py:390, in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     388     own_fid = False
#     389 else:
# --> 390     fid = stack.enter_context(open(os_fspath(file), "rb"))
#     391     own_fid = True
#     393 # Code to distinguish from NumPy binary files and pickles.
#
# FileNotFoundError: [Errno 2] No such file or directory: '../_out/test/train_ratio_0.7/rank_5/gamma_1/niter_3loss_logs.npy'

# %%
a
# Out:
# array([3.62341668e+09, 3.62341422e+09, 3.62341145e+09, ...,
#        2.97490500e+06, 2.97490500e+06, 2.97490500e+06])

# %%
plt.plot(a)

# %%
with open(f"{p}/result.pkl", 'rb') as f:
     d = pickle.load(f)

# %%
plt.plot(d.loss_logs)
