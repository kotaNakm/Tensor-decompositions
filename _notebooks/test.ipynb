# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

import numpy as np
import pandas
import dill 
import pickle
import tensorly
import matplotlib.pyplot as plt
import sys 
sys.path.append("../")
import factorization
# from agh import AGH
# sys.path.append("../_src/AGH/")
# from AGH import AGH

# %%
factorization.AGH()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [4], in <cell line: 1>()
# ----> 1 factorization.AGH()
#
# TypeError: __init__() missing 9 required positional arguments: 'tensor_shape', 'rank', 'initial_gamma', 'l0', 'L', 'negative_curvature', 'optimization', 'phai', and 'n_iter'

# %%
# p="../_out/test/train_ratio_0./rank_5/gamma_1/niter_3"
p="../_out/test/train_ratio_0.01/rank_5/gamma_0.1/l0_1e-100/niter_20"

# %%
# a=np.load(p+"loss_logs.npy")

with open(p+"/result.pkl","rb") as f:
    b = pickle.load(f)

# %%
c=b.loss_logs

# %%
plt.plot(c)

# %%
with open(f"{p}/result.pkl", 'rb') as f:
     d = pickle.load(f)

# %%
plt.plot(d.loss_logs)
