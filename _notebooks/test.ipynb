# %%
import numpy as np
import pandas

import tensorly
import matplotlib.pyplot as plt

# %%
a=np.load("../_out/test/loss_logs.npy")

# %%
a
# Out:
# array([140951.53506802, 140951.53506802, 140951.53506764, ...,
#        141070.58596979, 141070.58596979, 141070.58596979])

# %%
plt.plot(a)
